# %%
import pandas as pd
import numpy as np

userFeature_df = pd.read_csv("../data/MyUserFeature.csv",nrows=1000000,sep=',')
userFeature_df.head(10)
# Out:
#         uid  age  gender    LBS  consumptionAbility  education  \
# 0  26325489    4       2  950.0                   2          7
# 1   1184123    2       1  803.0                   1          2
# 2  76072711    1       1  927.0                   1          5
# 3  63071413    4       1  486.0                   1          7
# 4  81294159    5       1  112.0                   2          6
# 5  26419924    1       1  589.0                   0          2
# 6   3467967    4       1  244.0                   1          7
# 7  54125482    5       1  464.0                   1          2
# 8  29339838    5       1  585.0                   1          6
# 9   3741280    1       2  705.0                   1          7
#
#                      topic1                    topic2 topic3  \
# 0   9826 105 8525 5488 7281  9708 5553 6745 7477 7150    NaN
# 1  4391 9140 5669 1348 4388  9401 7724 1380 8890 7153    NaN
# 2  1502 5488 9826 2187 8088  5005 9154 2756 5612 4209    NaN
# ...

# %%
userFeature_df.shape[0] - userFeature_df.count()

# 先计算
# Out:
# uid                        0
# age                        0
# gender                     0
# LBS                        5
# consumptionAbility         0
# education                  0
# topic1                 79639
# topic2                 38560
# topic3                954026
# kw1                    94078
# kw2                    36534
# kw3                   954142
# carrier                    0
# ct                         0
# marriageStatus             0
# interest1              84884
# interest2             350267
# interest3             973579
# interest4             984958
# interest5             254507
# house                 816602
# os                         0
# appIdAction           984932
# appIdInstall          979619
# dtype: int64
